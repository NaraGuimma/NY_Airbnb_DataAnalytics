# %% [markdown]
# <a href="https://colab.research.google.com/github/NaraGuimma/NY_Airbnb_DataAnalytics/blob/master/ny_aibnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data_df = pd.read_csv("AB_NYC_2019.csv")

# %%
data_df
# Out:
#              id  ... availability_365
# 0          2539  ...              365
# 1          2595  ...              355
# 2          3647  ...              365
# 3          3831  ...              194
# 4          5022  ...                0
# ...         ...  ...              ...
# 48890  36484665  ...                9
# 48891  36485057  ...               36
# 48892  36485431  ...               27
# 48893  36485609  ...                2
# 48894  36487245  ...               23
#
# [48895 rows x 16 columns]

# %%
data_df.head(5)
# Out:
#      id  ... availability_365
# 0  2539  ...              365
# 1  2595  ...              355
# 2  3647  ...              365
# 3  3831  ...              194
# 4  5022  ...                0
#
# [5 rows x 16 columns]

# %%
data_df.tail(5)
# Out:
#              id  ... availability_365
# 48890  36484665  ...                9
# 48891  36485057  ...               36
# 48892  36485431  ...               27
# 48893  36485609  ...                2
# 48894  36487245  ...               23
#
# [5 rows x 16 columns]

# %%
data_df.shape
# Out:
# (48895, 16)

# %%
data_df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
data_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
data_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
columns_to_drop = ["id","host_name", "last_review"]
#inplace makes the changes on the dataframe if used equals True
data_df.drop(columns_to_drop, axis= "columns", inplace= True)

# %%
data_df.columns
# Out:
# Index(['name', 'host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
data_df.isnull().sum()
# Out:
# name                                 16
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
data_df.fillna({"reviews_per_month":0}, inplace=True )

# %%
data_df.isnull().sum()
# Out:
# name                              16
# host_id                            0
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
data_df["price"] < 100
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 48890     True
# 48891     True
# 48892    False
# 48893     True
# 48894     True
# Name: price, Length: 48895, dtype: bool

# %%
data_df[data_df["price"] < 100]
# Out:
#                                                     name  ...  availability_365
# 3                        Cozy Entire Floor of Brownstone  ...               194
# 4       Entire Apt: Spacious Studio/Loft by central park  ...                 0
# 6                                        BlissArtsSpace!  ...                 0
# 7                       Large Furnished Room Near B'way   ...               220
# 8                     Cozy Clean Guest Room - Family Apt  ...                 0
# ...                                                  ...  ...               ...
# 48889                                 QUIT PRIVATE HOUSE  ...               163
# 48890    Charming one bedroom - newly renovated rowhouse  ...                 9
# 48891      Affordable room in Bushwick/East Williamsburg  ...                36
# 48893               43rd St. Time Square-cozy single bed  ...                 2
# 48894  Trendy duplex in the very heart of Hell's Kitchen  ...                23
#
# ...

# %%
# printing just the top 10 records of the dataframe
data_df.head()
# Out:
#                                                name  ...  availability_365
# 0                Clean & quiet apt home by the park  ...               365
# 1                             Skylit Midtown Castle  ...               355
# 2               THE VILLAGE OF HARLEM....NEW YORK !  ...               365
# 3                   Cozy Entire Floor of Brownstone  ...               194
# 4  Entire Apt: Spacious Studio/Loft by central park  ...                 0
#
# [5 rows x 13 columns]

# %%
data_df.nlargest(10, "number_of_reviews")
# Out:
#                                                     name  ...  availability_365
# 11759                            Room near JFK Queen Bed  ...               333
# 2031                          Great Bedroom in Manhattan  ...               293
# 2030                      Beautiful Bedroom in Manhattan  ...               342
# 2015                        Private Bedroom in Manhattan  ...               339
# 13495                            Room Near JFK Twin Beds  ...               173
# 10623                  Steps away from Laguardia airport  ...               163
# 1879            Manhattan Lux Loft.Like.Love.Lots.Look !  ...               179
# 20403  Cozy Room Family Home LGA Airport NO CLEANING FEE  ...               341
# 4870                  Private brownstone studio Brooklyn  ...               269
# 471                      LG Private Room/Family Friendly  ...                 0
#
# [10 rows x 13 columns]

# %%
# the smallest numbers based on the number of reviews 
data_df.nsmallest(5, "number_of_reviews")
# Out:
#                                                  name  ...  availability_365
# 2                 THE VILLAGE OF HARLEM....NEW YORK !  ...               365
# 19                  Huge 2 BR Upper East  Cental Park  ...               249
# 26  Magnifique Suite au N de Manhattan - vue Cloitres  ...                 0
# 36                        Clean and Quiet in Brooklyn  ...               365
# 38                          Country space in the city  ...               365
#
# [5 rows x 13 columns]

# %%
# the top three most expensive places 
data_df.nlargest(3, "price")
# Out:
#                                                   name  ...  availability_365
# 9151               Furnished room in Astoria apartment  ...                 0
# 17692  Luxury 1 bedroom apt. -stunning Manhattan views  ...                 0
# 29238                              1-BR Lincoln Center  ...                83
#
# [3 rows x 13 columns]

# %%
# the smallest values based on the price
data_df.nsmallest(3, "price")
# Out:
#                                                     name  ...  availability_365
# 23161  Huge Brooklyn Brownstone Living, Close to it all.  ...                28
# 25433      ★Hostel Style Room | Ideal Traveling Buddies★  ...               127
# 25634    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)  ...                 0
#
# [3 rows x 13 columns]

# %%
# showing just the unique values for the column neighbourhood group
data_df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
# counting the values for each neighbourhood
data_df["neighbourhood"].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
# grouping just the types of rooms available
data_df["room_type"].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
# counting the values based on their neighbourhood group
data_df["neighbourhood_group"].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
# counting values for each neighbourhood and showing the top ten
data_df["neighbourhood"].value_counts().head(10)
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: neighbourhood, dtype: int64

# %%
# bar plot
data_df["neighbourhood"].value_counts().head(10).plot(kind = "bar")

# %%
# ploting using countplot from seaborn
sns.countplot(data = data_df, x ="neighbourhood_group")

# %%
sns.countplot(data = data_df, x ="room_type")

# %%
# ordering by neighbourhood group index number (descending)
order = dataset_df["neighbourhood_group"].value_counts().index

# %%
sns.countplot(data = data_df, x ="neighbourhood_group", order = order)

# %%
# analysing the relationship between the nighbourhood group and the room type
sns.countplot(data = data_df, x ="neighbourhood_group", hue="room_type")

# %%
sns.countplot(data = data_df, x ="price", hue="room_type")

# %%
# using displot to analyse the distribution
sns.distplot(data_df["price"])

# %%
cheap_df = data_df[data_df["price"] <= 500]

# %%
sns.distplot(cheap_df["price"])

# %%
# getting the mean price of the new dataframe 
cheap_df["price"].mean()
# Out:
# 131.53056362458466

# %%
plt.figure(figsize = (15,8))
sns.violinplot(data = cheap_df, x = "neighbourhood_group", y = "price")

# %%
cheap_df.plot(
    kind="scatter",
    x="longitude",
    y ="latitude",
    c="price",
    cmap ="inferno",
    colorbar=True,
    alpha=0.8,
    figsize=(12,8))

# %%
from IPython.display import Image
img = Image(filename='New_York_City_.png')

# %%
img

# %%
from PIL import Image

import numpy as np

img1 = Image.open("New_York_City_.png")

# %%
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1326x1291 at 0x7FCD04E67DD8>

# %%
import urllib
i = urllib.request.urlopen("https://upload.wikimedia.org/wikipedia/commons/e/ec/Neighbourhoods_New_York_City_Map.PNG")
plt.imshow(plt.imread(i), zorder = 0, extent = [-74.258, -73.7, 40.49, 40.92])
ax =plt.gca()
cheap_df.plot(
    ax=ax, 
    zorder=1, 
    kind='scatter',
    x = 'longitude',
    y='latitude',
    c='price',
    cmap='inferno',
    colorbar=True, 
    alpha=0.8, 
    figsize=(12,8)
)
